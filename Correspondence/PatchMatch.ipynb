# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np

import cv2
print('OpenCV version used:', cv2.__version__)

from matplotlib import pyplot as plt
import matplotlib as mpl

from myutils import *
from PatchMatch import PatchMatch
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# OpenCV version used: 4.1.0

# %%
mpl.rcParams['figure.figsize'] = (15,15)
mpl.rcParams['image.cmap'] = 'inferno'

# %%
url1 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/frames/v001.jpg"
url2 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/frames/v010.jpg"
img_s = url_to_image(url1)
img_t = url_to_image(url2)

img_s = imread('img/source.png')
img_t = imread('img/target.png')
RESIZE_FACTOR = 0.2
img_s = cv2.resize(img_s, (0,0), fx=RESIZE_FACTOR, fy=RESIZE_FACTOR)
img_t = cv2.resize(img_t, (0,0), fx=RESIZE_FACTOR, fy=RESIZE_FACTOR)
imshow(img_s, sub=(1,2,1))
imshow(img_t, sub=(1,2,2))
plt.show()
# imshow(np.abs(img_s.astype(int) - img_t.astype(int)).mean(2))

# %%
PM = PatchMatch(img_s, img_t)

PM.show_NNF(sub=(1,2,1));
PM.reconstruct(sub=(1,2,2));
plt.show()

# %%
PATCH_SIZE = 3
PM.run(5, PATCH_SIZE, show_iterations=True)
